# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading https://files.pythonhosted.org/packages/cc/d3/90e4ca88a1c42af9699e277dbb57f2f942e7f8e24c234611a394d74f88b7/pytrends-4.3.0-py2.py3-none-any.whl
# Requirement already satisfied: lxml in /home/chuck/anaconda3/lib/python3.6/site-packages (from pytrends)
# Requirement already satisfied: pandas in /home/chuck/anaconda3/lib/python3.6/site-packages (from pytrends)
# Requirement already satisfied: requests in /home/chuck/anaconda3/lib/python3.6/site-packages (from pytrends)
# Requirement already satisfied: python-dateutil>=2 in /home/chuck/anaconda3/lib/python3.6/site-packages (from pandas->pytrends)
# Requirement already satisfied: pytz>=2011k in /home/chuck/anaconda3/lib/python3.6/site-packages (from pandas->pytrends)
# Requirement already satisfied: numpy>=1.9.0 in /home/chuck/anaconda3/lib/python3.6/site-packages (from pandas->pytrends)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/chuck/anaconda3/lib/python3.6/site-packages (from requests->pytrends)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/chuck/anaconda3/lib/python3.6/site-packages (from requests->pytrends)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/chuck/anaconda3/lib/python3.6/site-packages (from requests->pytrends)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chuck/anaconda3/lib/python3.6/site-packages (from requests->pytrends)
# Requirement already satisfied: six>=1.5 in /home/chuck/anaconda3/lib/python3.6/site-packages (from python-dateutil>=2->pandas->pytrends)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.3.0
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pytrends.request import TrendReq
import pandas as pd


keyword = 'Bitcoin'
pytrend = TrendReq(hl='de-CH')

pytrend.build_payload(kw_list=[keyword], timeframe='today 1-m', geo='CH', gprop='news')

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
print(interest_over_time_df)
# Out:
#             Bitcoin  isPartial
# date
# 2018-04-05       63      False
# 2018-04-06       76      False
# 2018-04-07       63      False
# 2018-04-08       66      False
# 2018-04-09       64      False
# 2018-04-10       61      False
# 2018-04-11       48      False
# 2018-04-12       81      False
# 2018-04-13       77      False
# 2018-04-14       63      False
# 2018-04-15       61      False
# 2018-04-16      100      False
# 2018-04-17       73      False
# 2018-04-18       70      False
# 2018-04-19       60      False
# 2018-04-20       90      False
# 2018-04-21       43      False
# 2018-04-22       68      False
# 2018-04-23       64      False
# 2018-04-24       49      False
# 2018-04-25       68      False
# 2018-04-26       63      False
# 2018-04-27       74      False
# 2018-04-28       55      False
# 2018-04-29       55      False
# 2018-04-30       61      False
# 2018-05-01       53      False
# 2018-05-02       39      False

# %%
pytrend.suggestions(keyword = 'brew')
# Out:
# [{'mid': '/m/0159gt', 'title': 'Brauerei', 'type': 'Gebäudefunktion'},
#  {'mid': '/m/02zk2w',
#   'title': 'Binary Runtime Environment for Wireless',
#   'type': 'Thema'},
#  {'mid': '/m/01_l33', 'title': 'Mikrobrauerei', 'type': 'Thema'},
#  {'mid': '/m/01d_x', 'title': 'Bierbrauen', 'type': 'Thema'},
#  {'mid': '/m/07clx', 'title': 'Tee', 'type': 'Getränk'}]
