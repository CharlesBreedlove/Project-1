# %%
# Dependencies
import json
import requests

# Google developer API key
from config import gkey

# %%
# use census MSA lat/long in gAPI
# variables for x (lat) and y (long)
keywords=["brew", "brewpub", "brewery"]
lat = []
long = []

# %%
# Target city
target_city={"lat": 39.099727, "lng": -94.578567}
target_coords = f"{target_city['lat']},{target_city['lng']}"

params = {
    "location": target_coords,
    "radius": 8000,
    "keyword": keywords,
    "key": gkey
}

# Build the endpoint URL (Checks all ice cream shops)
base_url = "https://maps.googleapis.com/maps/api/place/radarsearch/json"

# Run a request to endpoint and convert result to json
brewery_data = requests.get(base_url, params=params)

# Print the assembled URL
print(brewery_data.url)

# Convert to JSON
brewery_data = brewery_data.json()

# Print the number of ice cream shops
print(len(brewery_data["results"]))
nu_of_relavent_results=len(brewery_data["results"])
nu_of_relavent_results
# Out:
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.099727%2C-94.578567&radius=8000&keyword=brew&keyword=brewpub&keyword=brewery&key=AIzaSyCLOAVbUwS4p5cD6xMHO2SHwNQqtWF8u1o
# 68
# 68

# %%
# The remaining code below is gPlace API -- we do not think we need this afterall
# WE don't care about names or gRankings at this point

# %%
# #  geocoordinates
# target_coordinates = "39.09426570000001, -94.6052916"
# # target_search = "Chinese"
# target_radius = 8000
# # target_type = "restaurant"
# name = "Brew"
# # name = ""

# # set up a parameters dictionary
# params = {
#     "location": target_coordinates,
# #     "keyword": target_search,
#     "radius": target_radius,
# #     "type": target_type,
#     "name": name,
#     "key": gkey
# }

# # base url
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# # run a request using our params dictionary
# response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
# print(response.url)

# %%
# convert response to json
# places_data = response.json()

# # Print the json (pretty printed)
# print(json.dumps(places_data, indent=4, sort_keys=True))

# %%
# Print the name and address of the first restaurant that appears
# print(places_data["results"][0]["name"])
# print(places_data["results"][0]["vicinity"])
